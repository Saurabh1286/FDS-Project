# %% [markdown]
# Datasets :
#
# 01. All_Month
# 02. Accidents_Collision
# 03. Accidents_Helmet
# 04. Accidents_Licence
# 05. Accidents_LoadCondition
# 06. Accidents_SeatBelt
# 07. Accidents_Time
# 08. Accidents_TrafficCondition
# 09. Accidents_TrafficViolations
# 10. Accidents_Type
# 11. Accidents_Weather
# 12. Deaths_Sex_Age
# 13. Deaths_RoadUser
# 14. Accidents_Total_2017_2020
# 15. Accidents_Fatal_2017_2020
# 16. Deaths_2017_2020
# 17. Injured_2017_2020
# 18. Total_1970_2020

# %%
path = r"C:\Users\user\Desktop\Project"
import pandas as pd

# %%
All_Month = pd.read_csv(rf"{path}\datasets\2020_All_MonthWise.csv")
All_Month
# Out:
#                  States/Uts  January - Fatal Accidents  \
# 0            Andhra Pradesh                      628.0
# 1         Arunachal Pradesh                        7.0
# 2                     Assam                      286.0
# 3                     Bihar                      535.0
# 4              Chhattisgarh                      419.0
# 5                       Goa                       30.0
# 6                   Gujarat                      602.0
# 7                   Haryana                      378.0
# 8          Himachal Pradesh                       63.0
# 9         Jammu and Kashmir                       46.0
# 10                Jharkhand                      271.0
# 11                Karnataka                      969.0
# 12                   Kerala                      373.0
# 13           Madhya Pradesh                      899.0
# 14              Maharashtra                     1123.0
# 15                  Manipur                       17.0
# ...

# %%
Accidents_Collision = pd.read_csv(rf"{path}\datasets\2020_Accidents_Collision.csv")
Accidents_Collision
# Out:
#                     States/UTs  Hit and Run - Total Accdents  \
# 0               Andhra Pradesh                        1196.0
# 1            Arunachal Pradesh                           7.0
# 2                        Assam                        1235.0
# 3                        Bihar                         774.0
# 4                 Chhattisgarh                        1539.0
# 5                          Goa                          36.0
# 6                      Gujarat                        1552.0
# 7                      Haryana                        2386.0
# 8             Himachal Pradesh                         411.0
# 9            Jammu and Kashmir                         337.0
# 10                   Jharkhand                         800.0
# 11                   Karnataka                        2193.0
# 12                      Kerala                        1118.0
# 13              Madhya Pradesh                       11550.0
# ...

# %%
Accidents_Helmet = pd.read_csv(rf"{path}\datasets\2020_Accidents_Helmet.csv")
Accidents_Helmet
# Out:
#                      States/Uts  Drivers - Persons Killed - Number  \
# 0                Andhra Pradesh                             1728.0
# 1             Arunachal Pradesh                                9.0
# 2                         Assam                              360.0
# 3                         Bihar                              238.0
# 4                  Chhattisgarh                             2198.0
# 5                           Goa                               90.0
# 6                       Gujarat                             1498.0
# 7                       Haryana                              365.0
# 8              Himachal Pradesh                               70.0
# 9             Jammu and Kashmir                               35.0
# 10                    Jharkhand                              754.0
# 11                    Karnataka                             1892.0
# 12                       Kerala                              297.0
# ...

# %%
Accidents_Licence = pd.read_csv(rf"{path}\datasets\2020_Accidents_Licence.csv")
Accidents_Licence
# Out:
#                          States  Valid Permanent License - Number  \
# 0                Andhra Pradesh                           13324.0
# 1             Arunachal Pradesh                              69.0
# 2                         Assam                            4511.0
# 3                         Bihar                            7250.0
# 4                  Chhattisgarh                            7019.0
# 5                           Goa                            2265.0
# 6                       Gujarat                           10433.0
# 7                       Haryana                            3710.0
# 8             Himachal Pradesh                             1410.0
# 9             Jammu and Kashmir                            3368.0
# 10                    Jharkhand                            1418.0
# 11                    Karnataka                           27568.0
# 12                       Kerala                           21380.0
# ...

# %%
Accidents_LoadCondition = pd.read_csv(rf"{path}\datasets\2020_Accidents_LoadCondition.csv")
Accidents_LoadCondition
# Out:
#                      States/UTs  Normally Loaded - No. of Accidents  \
# 0                Andhra Pradesh                             12138.0
# 1             Arunachal Pradesh                                81.0
# 2                         Assam                              3064.0
# 3                         Bihar                              6323.0
# 4                  Chhattisgarh                              5816.0
# 5                           Goa                              2375.0
# 6                       Gujarat                              8198.0
# 7                       Haryana                              1542.0
# 8              Himachal Pradesh                              1915.0
# 9             Jammu and Kashmir                              1718.0
# 10                    Jharkhand                              1643.0
# 11                    Karnataka                             25164.0
# 12                       Kerala                             25769.0
# ...

# %%
Accidents_SeatBelt = pd.read_csv(rf"{path}\datasets\2020_Accidents_SeatBelt.csv")
Accidents_SeatBelt
# Out:
#                      States/Uts  Drivers - Persons Killed - Number  \
# 0                Andhra Pradesh                              230.0
# 1             Arunachal Pradesh                                6.0
# 2                         Assam                              160.0
# 3                         Bihar                               68.0
# 4                  Chhattisgarh                              253.0
# 5                           Goa                                2.0
# 6                       Gujarat                              407.0
# 7                       Haryana                              232.0
# 8              Himachal Pradesh                              326.0
# 9             Jammu and Kashmir                               60.0
# 10                    Jharkhand                              519.0
# 11                    Karnataka                              350.0
# 12                       Kerala                               31.0
# ...

# %%
Accidents_Time = pd.read_csv(rf"{path}\datasets\2020_Accidents_Time.csv")
Accidents_Time
# Out:
#                  States/UTs  06-900hrs - Day  09-1200hrs - Day  \
# 0            Andhra Pradesh           2379.0            2955.0
# 1         Arunachal Pradesh             18.0              24.0
# 2                     Assam            764.0            1186.0
# 3                     Bihar           1425.0            1621.0
# 4              Chhattisgarh           1043.0            1691.0
# 5                       Goa            197.0             351.0
# 6                   Gujarat           1421.0            2067.0
# 7                   Haryana           1019.0            1182.0
# 8          Himachal Pradesh            189.0             321.0
# 9         Jammu and Kashmir            502.0             862.0
# 10                Jharkhand            580.0             748.0
# 11                Karnataka           3580.0            4939.0
# 12                   Kerala           3298.0            5238.0
# 13           Madhya Pradesh           3666.0            6200.0
# ...

# %%
Accidents_TrafficCondition = pd.read_csv(rf"{path}\datasets\2020_Accidents_TrafficControl.csv")
Accidents_TrafficCondition
# Out:
#                     States/UTs  \
# 0               Andhra Pradesh
# 1            Arunachal Pradesh
# 2                        Assam
# 3                        Bihar
# 4                 Chhattisgarh
# 5                          Goa
# 6                      Gujarat
# 7                      Haryana
# 8             Himachal Pradesh
# 9            Jammu and Kashmir
# 10                   Jharkhand
# 11                   Karnataka
# 12                      Kerala
# 13              Madhya Pradesh
# 14                 Maharashtra
# 15                     Manipur
# 16                   Meghalaya
# 17                     Mizoram
# 18                    Nagaland
# 19                      Orissa
# 20                      Punjab
# 21                   Rajasthan
# 22                      Sikkim
# 23                  Tamil Nadu
# 24                   Telangana
# 25                     Tripura
# 26                 Uttarakhand
# 27               Uttar Pradesh
# 28                 West Bengal
# ...

# %%
Accidents_TrafficViolations = pd.read_csv(rf"{path}\datasets\2020_Accidents_TrafficViolation.csv")
Accidents_TrafficViolations
# Out:
#                      States/UTs  Over-Speeding - Number of Accidents - Number  \
# 0                Andhra Pradesh                                       14716.0
# 1             Arunachal Pradesh                                          64.0
# 2                         Assam                                        4586.0
# 3                         Bihar                                        3298.0
# 4                  Chhattisgarh                                        9996.0
# 5                           Goa                                        1845.0
# 6                       Gujarat                                       12449.0
# 7                       Haryana                                        6251.0
# 8              Himachal Pradesh                                        1383.0
# 9             Jammu and Kashmir                                        4821.0
# 10                    Jharkhand                                        3136.0
# ...

# %%
Accidents_Type = pd.read_csv(rf"{path}\datasets\2020_Accidents_Type.csv")
Accidents_Type
# Out:
#                     States/UTs  Fatal Accidents  Grievous Injury Accidents  \
# 0               Andhra Pradesh           6531.0                     3458.0
# 1            Arunachal Pradesh             61.0                       60.0
# 2                        Assam           2483.0                     3375.0
# 3                       Bihar            6197.0                     1873.0
# 4                Chhattisgarh            4234.0                     1252.0
# 5                          Goa            213.0                      150.0
# 6                      Gujarat           5622.0                     4522.0
# 7                     Haryana            4181.0                     1538.0
# 8             Himachal Pradesh            734.0                      761.0
# 9            Jammu and Kashmir            623.0                     2046.0
# 10                   Jharkhand           2775.0                     1217.0
# ...

# %%
Accidents_Weather = pd.read_csv(rf"{path}\datasets\2020_Accidents_Weather.csv")
Accidents_Weather
# Out:
#                     States/UTs  Sunny/Clear - Total Accidents - Number  \
# 0               Andhra Pradesh                                 14836.0
# 1            Arunachal Pradesh                                    36.0
# 2                        Assam                                  2792.0
# 3                        Bihar                                  4436.0
# 4                 Chhattisgarh                                  8426.0
# 5                          Goa                                  2185.0
# 6                      Gujarat                                 11348.0
# 7                      Haryana                                  3771.0
# 8             Himachal Pradesh                                  2028.0
# 9            Jammu and Kashmir                                  3440.0
# 10                   Jharkhand                                  1828.0
# 11                   Karnataka                                 28928.0
# ...

# %%
Deaths_Sex_Age = pd.read_csv(rf"{path}\datasets\2020_Deaths_Age_Sex.csv")
Deaths_Sex_Age
# Out:
#                        State/UT  Less than 18 years - Male  \
# 0                Andhra Pradesh                      322.0
# 1             Arunachal Pradesh                        4.0
# 2                         Assam                      188.0
# 3                         Bihar                      467.0
# 4                  Chhattisgarh                      185.0
# 5                           Goa                        6.0
# 6                       Gujarat                      207.0
# 7                       Haryana                      208.0
# 8              Himachal Pradesh                       33.0
# 9             Jammu and Kashmir                       28.0
# 10                    Jharkhand                      193.0
# 11                    Karnataka                      232.0
# 12                       Kerala                       57.0
# 13               Madhya Pradesh                      531.0
# 14                  Maharashtra                      205.0
# ...

# %%
Deaths_RoadUser = pd.read_csv(rf"{path}\datasets\2020_Deaths_RoadUser_Sex.csv")
Deaths_RoadUser
# Out:
#                     States/Uts  Pedestrian - Male  Pedestrian - Female  \
# 0               Andhra Pradesh              986.0                286.0
# 1            Arunachal Pradesh                1.0                  1.0
# 2                        Assam              511.0                107.0
# 3                        Bihar             2176.0                473.0
# 4                 Chhattisgarh              469.0                106.0
# 5                          Goa               22.0                  7.0
# 6                      Gujarat             1000.0                199.0
# 7                      Haryana              600.0                 58.0
# 8             Himachal Pradesh              110.0                 35.0
# 9            Jammu and Kashmir               68.0                 33.0
# 10                   Jharkhand              230.0                 37.0
# 11                   Karnataka             1333.0                259.0
# ...

# %%
Accidents_Total_2017_2020 = pd.read_csv(rf"{path}\datasets\2017-2020_Accidents_Total.csv")
Accidents_Total_2017_2020
# Out:
#                      States/UTs  \
# 0                Andhra Pradesh
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                  Chhattisgarh
# 5                           Goa
# 6                       Gujarat
# 7                       Haryana
# 8              Himachal Pradesh
# 9             Jammu and Kashmir
# 10                    Jharkhand
# 11                    Karnataka
# 12                       Kerala
# 13               Madhya Pradesh
# 14                  Maharashtra
# 15                      Manipur
# 16                    Meghalaya
# 17                      Mizoram
# 18                     Nagaland
# 19                       Odisha
# 20                       Punjab
# 21                    Rajasthan
# 22                       Sikkim
# 23                   Tamil Nadu
# 24                    Telangana
# 25                      Tripura
# 26                  Uttarakhand
# 27                Uttar Pradesh
# ...

# %%
Accidents_Fatal_2017_2020 = pd.read_csv(rf"{path}\datasets\2017-2020_Fatal_Accidents.csv")
Accidents_Fatal_2017_2020
# Out:
#                      States/UTs  Number of Fatal Road Accidents in 2017  \
# 0                Andhra Pradesh                                    7564
# 1             Arunachal Pradesh                                     103
# 2                         Assam                                    2474
# 3                         Bihar                                    5045
# 4                  Chhattisgarh                                    3878
# 5                           Goa                                     306
# 6                       Gujarat                                    6739
# 7                       Haryana                                    4700
# 8              Himachal Pradesh                                     907
# 9             Jammu and Kashmir                                     765
# 10                    Jharkhand                                    3034
# 11                    Karnataka                                    9739
# ...

# %%
Deaths_2017_2020 = pd.read_csv(rf"{path}\datasets\2017-2020_Deaths_Total.csv")
Deaths_2017_2020
# Out:
#                      States/UTs  \
# 0                Andhra Pradesh
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                  Chhattisgarh
# 5                           Goa
# 6                       Gujarat
# 7                       Haryana
# 8              Himachal Pradesh
# 9             Jammu and Kashmir
# 10                    Jharkhand
# 11                    Karnataka
# 12                       Kerala
# 13               Madhya Pradesh
# 14                  Maharashtra
# 15                      Manipur
# 16                    Meghalaya
# 17                      Mizoram
# 18                     Nagaland
# 19                       Odisha
# 20                       Punjab
# 21                    Rajasthan
# 22                       Sikkim
# 23                   Tamil Nadu
# 24                    Telangana
# 25                      Tripura
# 26                  Uttarakhand
# 27                Uttar Pradesh
# ...

# %%
Injured_2017_2020 = pd.read_csv(rf"{path}\datasets\2017-2020_Injured_Total.csv")
Injured_2017_2020
# Out:
#                    States/UTs  \
# 0              Andhra Pradesh
# 1           Arunachal Pradesh
# 2                       Assam
# 3                       Bihar
# 4                Chhattisgarh
# 5                         Goa
# 6                     Gujarat
# 7                     Haryana
# 8            Himachal Pradesh
# 9             Jammu & Kashmir
# 10                  Jharkhand
# 11                  Karnataka
# 12                     Kerala
# 13             Madhya Pradesh
# 14                Maharashtra
# 15                    Manipur
# 16                  Meghalaya
# 17                    Mizoram
# 18                   Nagaland
# 19                     Odisha
# 20                     Punjab
# 21                  Rajasthan
# 22                     Sikkim
# 23                 Tamil Nadu
# 24                  Telangana
# 25                    Tripura
# 26                Uttarakhand
# 27              Uttar Pradesh
# 28                West Bengal
# 29  Andaman & Nicobar Islands
# ...

# %%
Total_1970_2020 = pd.read_csv(rf"{path}\datasets\1970-2020_Total.csv")
Total_1970_2020
# Out:
#              Years  Total Number of Road Accidents (in numbers)   \
# 0             1970                                 114100.000000
# 1             1980                                 153200.000000
# 2             1990                                 282600.000000
# 3             1994                                 325864.000000
# 4             1995                                 351999.000000
# 5             1996                                 371204.000000
# 6             1997                                 373671.000000
# 7             1998                                 385018.000000
# 8             1999                                 386456.000000
# 9             2000                                 391449.000000
# 10            2001                                 405637.000000
# 11            2002                                 407497.000000
# 12            2003                                 406726.000000
# ...

# %%
Total_1970_2020.loc[28, "Road Length (in kms)"] = 6331757
Total_1970_2020.loc[29, "Road Length (in kms)"] = 6671083
Total_1970_2020.loc[29, "Total Number of Registered Motor Vehicles (in thousands) "] = 326299
Total_1970_2020.loc[28, "Number of Accidents per Ten Thousand Kms of Roads "] = Total_1970_2020.loc[28, "Total Number of Road Accidents (in numbers) "] / Total_1970_2020.loc[28, "Road Length (in kms)"] * 10000
Total_1970_2020.loc[28, "Number of Persons Killed per Ten Thousand Kms of Roads "] = Total_1970_2020.loc[28, "Total Number of Persons Killed (in numbers) "] / Total_1970_2020.loc[28, "Road Length (in kms)"] * 10000
Total_1970_2020.loc[28, "Number of Persons Injured Per Ten Thousand Kms of Roads "] = Total_1970_2020.loc[28, "Total Number of Persons Injured (in numbers)"] / Total_1970_2020.loc[28, "Road Length (in kms)"] * 10000
Total_1970_2020.loc[29, "Number of Accidents per Ten Thousand Kms of Roads "] = Total_1970_2020.loc[29, "Total Number of Road Accidents (in numbers) "] / Total_1970_2020.loc[29, "Road Length (in kms)"] * 10000
Total_1970_2020.loc[29, "Number of Persons Killed per Ten Thousand Kms of Roads "] = Total_1970_2020.loc[29, "Total Number of Persons Killed (in numbers) "] / Total_1970_2020.loc[29, "Road Length (in kms)"] * 10000
Total_1970_2020.loc[29, "Number of Persons Injured Per Ten Thousand Kms of Roads "] = Total_1970_2020.loc[29, "Total Number of Persons Injured (in numbers)"] / Total_1970_2020.loc[29, "Road Length (in kms)"] * 10000
Total_1970_2020.loc[29, "Number of Accidents per Ten Thousand Vehicles"] = Total_1970_2020.loc[29, "Total Number of Road Accidents (in numbers) "] / Total_1970_2020.loc[29, "Total Number of Registered Motor Vehicles (in thousands) "] * 10
Total_1970_2020.loc[29, "Number of Persons Killed Per Ten Thousand Vehicles "] = Total_1970_2020.loc[29, "Total Number of Persons Killed (in numbers) "] / Total_1970_2020.loc[29, "Total Number of Registered Motor Vehicles (in thousands) "] * 10
Total_1970_2020.loc[29, "Number of Persons Injured Per Ten Thousand Vehicles"] = Total_1970_2020.loc[29, "Total Number of Persons Injured (in numbers)"] / Total_1970_2020.loc[29, "Total Number of Registered Motor Vehicles (in thousands) "] * 10

# %%
Cols_Acc = [c for c in All_Month.columns if c.split(" ")[-1] == "Accdents"]
Dict_Acc = {c : " ".join(c.split(" ")[:-1] + ["Accidents"]) for c in Cols_Acc}
All_Month.rename(columns = Dict_Acc, inplace = True)

# %%
Dataframes = [All_Month,Accidents_Collision,Accidents_Helmet,Accidents_Licence,Accidents_LoadCondition,Accidents_SeatBelt,Accidents_Time,Accidents_TrafficCondition,Accidents_TrafficViolations,Accidents_Type,Accidents_Weather,Deaths_Sex_Age,Deaths_RoadUser,Accidents_Total_2017_2020,Accidents_Fatal_2017_2020,Deaths_2017_2020,Injured_2017_2020]
for i in Dataframes :
    i.rename(columns = {i.columns[0] : "States/UTs"}, inplace = True)

# %%
Accidents_Collision.rename(columns = {"other - Total Accdents" : "Others - Total Accidents"}, inplace = True)

# %%
Dataframes = [All_Month,Accidents_Collision,Accidents_Helmet,Accidents_Licence,Accidents_LoadCondition,Accidents_SeatBelt,Accidents_Time,Accidents_TrafficCondition,Accidents_TrafficViolations,Accidents_Type,Accidents_Weather,Deaths_Sex_Age,Deaths_RoadUser,Accidents_Total_2017_2020,Accidents_Fatal_2017_2020,Deaths_2017_2020,Injured_2017_2020]
for i in Dataframes :
    i.drop(i[i["States/UTs"] == "Daman and Diu"].index, inplace = True)
    i.reset_index(drop = True, inplace = True)

Injured_2017_2020.drop(Injured_2017_2020[Injured_2017_2020["States/UTs"] == "Daman & Diu"].index, inplace = True)
Injured_2017_2020.reset_index(drop = True, inplace = True)

# %%
Accidents_Total_2017_2020.loc[Accidents_Total_2017_2020["States/UTs"] == "Telangana", "Total Number of Accidents Per Lakh Population - 2017"] = 64.2
Accidents_Total_2017_2020.loc[Accidents_Total_2017_2020["States/UTs"] == "Telangana", "Total Number of Accidents Per Lakh Population - 2018"] = 63.5
Accidents_Total_2017_2020.loc[Accidents_Total_2017_2020["States/UTs"] == "Telangana", "Total Number of Accidents Per Lakh Population - 2019"] = 61.6
Accidents_Total_2017_2020.loc[Accidents_Total_2017_2020["States/UTs"] == "Telangana", "Total Number of Accidents Per Lakh Population - 2020"] = 54.7

# %%
Injured_2017_2020.loc[Injured_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2017"] = 21.878301
Injured_2017_2020.loc[Injured_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Injured in Road Accidents Per Lakh Population - 2017"] = 68.535662
Injured_2017_2020.loc[Injured_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Injured in Road Accidents Per Lakh Population - 2018"] = 67.458633
Injured_2017_2020.loc[Injured_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Injured in Road Accidents Per Lakh Population - 2019"] = 62.847688
Injured_2017_2020.loc[Injured_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Injured in Road Accidents Per Lakh Population - 2020"] = 53.311546

# %%
Deaths_2017_2020.loc[Deaths_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Killed in Road Accidents Per Lakh Population - 2017"] = 18.843736 
Deaths_2017_2020.loc[Deaths_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Killed in Road Accidents Per Lakh Population - 2018"] = 18.863734
Deaths_2017_2020.loc[Deaths_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Killed in Road Accidents Per Lakh Population - 2019"] = 19.895054
Deaths_2017_2020.loc[Deaths_2017_2020["States/UTs"] == "Telangana", "Total Number of Persons Killed in Road Accidents Per Lakh Population - 2020"] = 19.660793

# %%
Dataframes = [All_Month,Accidents_Collision,Accidents_Helmet,Accidents_Licence,Accidents_LoadCondition,Accidents_SeatBelt,Accidents_Time,Accidents_TrafficCondition,Accidents_TrafficViolations,Accidents_Type,Accidents_Weather,Deaths_Sex_Age,Deaths_RoadUser,Accidents_Total_2017_2020,Accidents_Fatal_2017_2020,Deaths_2017_2020,Injured_2017_2020]
for i in Dataframes :
    columns = i.columns[1:]
    for j in columns :
        i.loc[35, j] = i[j][:-1].sum()

# %%
Dataframes = [All_Month,Accidents_Collision,Accidents_Helmet,Accidents_Licence,Accidents_LoadCondition,Accidents_SeatBelt,Accidents_Time,Accidents_TrafficCondition,Accidents_TrafficViolations,Accidents_Type,Accidents_Weather,Deaths_Sex_Age,Deaths_RoadUser,Accidents_Total_2017_2020,Accidents_Fatal_2017_2020,Deaths_2017_2020,Injured_2017_2020]
Cols_Rank = []
for i in Dataframes :
    Cols_Rank.append([c for c in i.columns if c.split(" ")[-1] == "Rank"])    
for i,j in zip(Dataframes, Cols_Rank) :
    i.drop(j, axis = 1, inplace = True)

# %%
Dataframes = [All_Month,Accidents_Collision,Accidents_Helmet,Accidents_Licence,Accidents_LoadCondition,Accidents_SeatBelt,Accidents_Time,Accidents_TrafficCondition,Accidents_TrafficViolations,Accidents_Type,Accidents_Weather,Deaths_Sex_Age,Deaths_RoadUser,Accidents_Total_2017_2020,Accidents_Fatal_2017_2020,Deaths_2017_2020,Injured_2017_2020]
Cols_Rank = []
for i in Dataframes :
    Cols_Rank.append([c for c in i.columns if c.split(" ")[-1] == "Number" or c.split(" ")[-1] == "Numbers"])   
Dict_Cols_Rank = []
for i in Cols_Rank :
    Dict_Cols_Rank.append({j : j.rsplit(' - ', 1)[0] for j in i})
for i,j in zip(Dataframes,Dict_Cols_Rank) :
    i.rename(columns = j, inplace = True)

# %%
Cols = {"State/UT-Wise Total Number of Road Accidents during 2017" : "Total Number of Road Accidents - 2017", "State/UT-Wise Total Number of Road Accidents during 2018" : "Total Number of Road Accidents - 2018", "State/UT-Wise Total Number of Road Accidents during 2019" : "Total Number of Road Accidents - 2019", "State/UT-Wise Total Number of Road Accidents during 2020" : "Total Number of Road Accidents - 2020"}
Accidents_Total_2017_2020.rename(columns=Cols, inplace = True)

# %%
Cols = {c :" ".join(c.split(" ")[1:-3] + c.split(" ")[-2:]) for c in Deaths_2017_2020.columns if c.split(" ")[0] == "State/UT-Wise"}
Deaths_2017_2020.rename(columns = Cols, inplace = True)

# %%
Cols = {c :" ".join(c.split(" ")[1:-3] + c.split(" ")[-2:]) for c in Injured_2017_2020.columns if c.split(" ")[0] == "State/UT-Wise"}
Injured_2017_2020.rename(columns = Cols, inplace = True)

# %%
Accidents_2020_per_10000_vehicles = [14.9,5.8,15.1,8.7,16.7,16.3,5.0,11.0,13.1,8.7,13.1,19.7,25.3,6.6,11.9,5.9,2.0,9.6,10.8,4.6,9.9,25.5,15.5,14.9,8.5,3.6,9.8,10.0,9.4,1.5,3.7,3.5,24.7,0.4,8.7,11.4]
Deaths_2020_per_10000_vehicles = [5.4,3.2,6.0,6.8,6.6,1.5,2.3,5.2,5.2,6.0,3.7,2.1,6.2,3.1,3.5,3.9,1.6,1.0,5.2,3.4,4.8,8.7,4.5,5.3,3.5,2.3,5.5,4.7,0.9,0.5,2.4,1.0,3.7,0.0,1.3,4.2]
Injured_2020_per_10000_vehicles = [15.0,8.0,12.1,7.1,15.0,6.0,4.5,8.9,18.8,6.5,15.1,21.5,25.9,5.3,18.3,6.0,2.5,5.5,9.7,2.6,8.7,40.3,14.8,14.5,8.5,2.9,6.4,8.9,9.7,1.4,4.4,3.1,30.0,0.4,9.1,10.6]
Accidents_2019_per_10000km_Roads = [1247.1,42.9,209.2,335.6,1322.8,1839.8,683.6,2176.1,392.3,642.1,1134.7,1581.6,1388.0,517.0,207.5,119.7,38.2,94.5,362.0,429.3,749.0,133.0,2311.9,1534.6,145.2,196.7,961.2,445.9,1271.5,1185.5,600.3,3469.3,482.9,43.1,3241.8,841.3]
Deaths_2019_per_10000km_Roads = [452.7,23.0,80.4,241.6,476.1,158.8,296.3,1005.5,156.5,467.8,305.8,170.8,308.2,200.8,48.2,44.5,29.5,6.9,174.5,306.0,337.0,59.9,668.6,495.5,53.0,126.2,511.5,203.2,110.6,404.3,432.5,904.7,83.0,0.0,342.3,292.7]
Injured_2019_per_10000km_Roads = [1396.0,55.9,187.2,241.6,1245.8,774.4,652.0,1861.5,669.7,469.9,1408.0,1771.8,1446.8,449.5,325.7,55.1,34.5,65.0,365.7,257.8,733.1,261.0,2328.4,1565.2,180.9,212.0,653.2,414.3,1144.3,1068.9,926.9,3186.1,627.5,43.1,3770.5,827.3]

# %%
Injured_2017_2020.rename(columns={"Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2019" : "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2020", "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2018" : "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2019", "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2017" : "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2018", "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2016" : "Total Number of Persons injured in Road Accidents per 10,000 Vehicles - 2017", "Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2018" : "Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2019", "Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2017" : "Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2018", "Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2016" : "Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2017"}, inplace = True)
Injured_2017_2020["Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2020"] = Injured_2019_per_10000km_Roads

# %%
Deaths_2017_2020.insert(16, "Total Number of Persons Killed in Road Accidents per 10,000 Vehicles - 2020", Deaths_2020_per_10000_vehicles)
Deaths_2017_2020.insert(19, "Total Number of Persons Killed in Road Accidents per 10,000 Km of Roads - 2019", Deaths_2019_per_10000km_Roads)

# %%
Accidents_Total_2017_2020.insert(16, "Total Number of Road Accidents per 10,000 Vehicles - 2020", Accidents_2020_per_10000_vehicles)
Accidents_Total_2017_2020.insert(19, "Total Number of Road Accidents per 10,000 Km of Roads - 2019", Accidents_2019_per_10000km_Roads)

# %%
Road_Length_2020 = Injured_2017_2020["Total Number of Persons Injured in Road Accidents - 2020"] / Injured_2017_2020["Total Number of Persons injured in Road Accidents per 10,000 Km of Roads - 2020"]
Deaths_2020_per_10000km_Roads = Deaths_2017_2020["Total Number of Persons Killed in Road Accidents - 2020"] / Road_Length_2020
Deaths_2017_2020.insert(20, "Total Number of Persons Killed in Road Accidents per 10,000 Km of Roads - 2020", Deaths_2020_per_10000km_Roads)

# %%
Accidents_2020_per_10000km_Roads = Accidents_Total_2017_2020["Total Number of Road Accidents - 2020"] / Road_Length_2020
Accidents_Total_2017_2020.insert(20,"Total Number of Persons Killed in Road Accidents per 10,000 Km of Roads - 2020", Accidents_2020_per_10000km_Roads)

# %%
All_Month.to_csv(rf"{path}\datasets\New\2020_All_MonthWise.csv", index = False)
Accidents_Collision.to_csv(rf"{path}\datasets\New\2020_Accidents_Collision.csv", index = False)
Accidents_Helmet.to_csv(rf"{path}\datasets\New\2020_Accidents_Helmet.csv", index = False)
Accidents_Licence.to_csv(rf"{path}\datasets\New\2020_Accidents_Licence.csv", index = False)
Accidents_LoadCondition.to_csv(rf"{path}\datasets\New\2020_Accidents_LoadCondition.csv", index = False)
Accidents_SeatBelt.to_csv(rf"{path}\datasets\New\2020_Accidents_SeatBelt.csv", index = False)
Accidents_Time.to_csv(rf"{path}\datasets\New\2020_Accidents_Time.csv", index = False)
Accidents_TrafficCondition.to_csv(rf"{path}\datasets\New\2020_Accidents_TrafficControl.csv", index = False)
Accidents_TrafficViolations.to_csv(rf"{path}\datasets\New\2020_Accidents_TrafficViolation.csv", index = False)
Accidents_Type.to_csv(rf"{path}\datasets\New\2020_Accidents_Type.csv", index = False)
Accidents_Weather.to_csv(rf"{path}\datasets\New\2020_Accidents_Weather.csv", index = False)
Deaths_Sex_Age.to_csv(rf"{path}\datasets\New\2020_Deaths_Age_Sex.csv", index = False)
Deaths_RoadUser.to_csv(rf"{path}\datasets\New\2020_Deaths_RoadUser_Sex.csv", index = False)
Accidents_Total_2017_2020.to_csv(rf"{path}\datasets\New\2017-2020_Accidents_Total.csv", index = False)
Accidents_Fatal_2017_2020.to_csv(rf"{path}\datasets\New\2017-2020_Fatal_Accidents.csv", index = False)
Deaths_2017_2020.to_csv(rf"{path}\datasets\New\2017-2020_Deaths_Total.csv", index = False)
Injured_2017_2020.to_csv(rf"{path}\datasets\New\2017-2020_Injured_Total.csv", index = False)
Total_1970_2020.to_csv(rf"{path}\datasets\New\1970-2020_Total.csv", index = False)
